# %% [markdown]
# # Sliding DFT Example
#
# This class implements a multi-frequency detection network utilizing a shared comb network followed by N-parallel real-signal recursive resonator networks.
#
# https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=8026592
# https://digital.library.adelaide.edu.au/dspace/bitstream/2440/133370/3/hdl_133370.pdf

# %%
from typing import Tuple
import math
import matplotlib.pyplot as plt
import generic
plt.rcParams['figure.figsize'] = [30, 10]
plt.grid()

# %%
class RealResonator:
    def __init__(self, **kwargs):
        

class mSDFT:
    def __init__(self, **kwargs):
        numDetectors = kwargs.get('num_detectors', 1)
        self.comb = generic.CombFilter()
        self.resonators = [RealResonator() for _ in numDetectors]
        
    def evaluate_at_frequency(self, freq: float, sample_rate: float) -> Tuple:
        responses = [
            self.comb.evaluate_at_frequency(freq, sample_rate)
        ]
        for r in self.resonators:
            responses.append(
                r.evaluate_at_frequency(freq, sample_rate)
            )
        magnitude = responses[0][0] * responses[1][0]
# Out:
#   File "<ipython-input-5-89c5fb2220ff>", line 5
#     class mSDFT:
#                 ^
# IndentationError: expected an indented block
